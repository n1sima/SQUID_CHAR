# %% [markdown]
# # V2Phi0 for Run53 SQUID 3 und 7

# %%
import scipy.signal as sig
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import pandas as pd
import scipy.optimize as so
import os

# %%
def  newplotVPhi0(fname):
    
    nhead = 12
    toVolt = 39.3216/((2**16) -1)
    fd = open(fname, 'rb')
    read_data = np.fromfile(file=fd, dtype=np.int16)#.reshape(shape)
    fd.close()
    dat = toVolt*read_data[nhead:]
    xs = np.arange(len(dat))
    y=dat**2
    min_index = np.argmin(y)
    min_x = xs[min_index]
    min_y = y[min_index]
    Nav=min_x-10
    V0 = np.mean(dat[:Nav])
    V2 = np.mean(dat[-Nav:])
    V=1e3*(V0-V2)
    plt.plot(xs, dat)
    print(V0,V2,V)
    plt.plot(xs, dat)
    plt.axhline(y=V0, color='r', linestyle='--', label='y = V0 ({:.2f})'.format(V0))
    plt.axhline(y=V2, color='g', linestyle='--', label='y = V2 ({:.2f})'.format(V2))
    plt.axvline(x=Nav, color='r', linestyle='--', label=r'$Nav = {:.2f}$'.format(Nav))
    plt.axvline(x=len(dat)-Nav, color='g', linestyle='--', label=r'$Len(data)-Nav = {:.2f}$'.format(len(dat)-Nav))
    plt.title(fname)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def avgVPhi0(fname):
    

    nhead = 12
    toVolt = 39.3216/((2**16) -1)
    fd = open(fname, 'rb')
    read_data = np.fromfile(file=fd, dtype=np.int16)#.reshape(shape)
    fd.close()
    dat = toVolt*read_data[nhead:]
    xs = np.arange(len(dat))
    y=dat**2
    min_index = np.argmin(y)
    min_x = xs[min_index]
    min_y = y[min_index]
    Nav=min_x-10

   
      



    V0 = np.mean(dat[:Nav])
    V2 = np.mean(dat[-Nav:])

    A = abs(1e3*(V0-V2))
    print('V/Phi0 = %.2f mV'%(A))
    
    return A

# %%
data=[]
L=[]
for i in range(2):
    file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\run54\squidchar_V_Phi0_S3L_0"+str(i)+'.bin')
    print("squidchar_resets_S3" + str(i)+"L")
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        newplotVPhi0(file_path)
        L.append(avgVPhi0(file_path))

        
    
    else:
        print("No data taken")
data.append(L)
L=[]
# Out:
# squidchar_resets_S30L
# No data taken
# squidchar_resets_S31L
# No data taken

# %%
L1=[]
for i in range(2):
    file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\run54\squidchar_V_Phi0_S3M_0"+str(i)+'.bin')
    print("squidchar_resets_S3" + str(i)+"M")
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        newplotVPhi0(file_path)
        L1.append(avgVPhi0(file_path))
        
    
    else:
        print("No data taken")
data.append(L1)
L1=[]
# Out:
# squidchar_resets_S30M
# No data taken
# squidchar_resets_S31M
# No data taken

# %%
L2=[]
for i in range(2):
    file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\run54\squidchar_V_Phi0_S7L_0"+str(i)+'.bin')
    print("squidchar_resets_S7" + str(i)+"L")
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        newplotVPhi0(file_path)
        L2.append(avgVPhi0(file_path))
        
    
    else:
        print("No data taken")
data.append(L2)
L2=[]    
 
L3=[]
for i in range(2):
    file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\run54\squidchar_V_Phi0_S7M_0"+str(i)+'.bin')
    print("squidchar_resets_S7" + str(i)+"M")
    
    if os.path.isfile(file_path):
        #readRDT(file_path)
        newplotVPhi0(file_path)
        L3.append(avgVPhi0(file_path))
    
    
    else:
        print("No data taken")
data.append(L3)
L3=[]
# Out:
# squidchar_resets_S70L
# No data taken
# squidchar_resets_S71L
# No data taken
# squidchar_resets_S70M
# No data taken
# squidchar_resets_S71M
# No data taken

# %%
print(data)
# Out:
# [[], [], [], []]

# %%
row_names = ["S3L", "S3M", "S7L", "S7M"]
df = pd.DataFrame(data,index=row_names)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [S3L, S3M, S7L, S7M]

# %%
file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\Bachelor Thesis\Run0008\squidchar_191_1_M_reset0000.bin")
newplotVPhi0(file_path)
# Out:
# 3.96807731188915 1.9664000899458305 2001.6772219433196
# C:\Users\n1cos\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\Bachelor Thesis\Run0008\squidchar_191_2_M_reset0000.bin")
newplotVPhi0(file_path)
# Out:
# 1.9844120867038 -0.5724370640501822 2556.8491507539825

# %%
file_path = (r"C:\Users\n1cos\OneDrive\Documentos\Semester 6\Bachelor Thesis\Run0008\squidchar_186_3_M_reset000.bin")
newplotVPhi0(file_path)
# Out:
# 1.013256901436122 0.0398159927900394 973.4409086460824
